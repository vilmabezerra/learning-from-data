# %% [markdown]
# # Relatório Final
#
# ### Inteligência Computacional II
#
# #### Aluna: Vilma Bezerra

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %% [markdown]
# ## Experimento 1

# %%
data = pd.read_csv('banana.dat', header=None)

# %% [markdown]
# ### Parte 1
#
# #### Geração da base de dados Banana

# %%
plt.scatter(data[0], data[1], c= data[2],  
            marker= "*", s=20)

# %% [markdown]
# Pode-se observar que os dados já se encontram num certo padrão que é de certa forma desafiador para uma aplicação eficaz de um modelo de classificação.

# %% [markdown]
# ### Parte 2
#
# #### Testando SVM e seus diferentes kernels na separação dos dados

# %%
classifiers = {
    "Sigmoid - gamma 1": SVC(kernel='sigmoid', gamma=1), 
    "Sigmoid - gamma .5": SVC(kernel='sigmoid', gamma=0.5), 
    "Sigmoid - gamma .01": SVC(kernel='sigmoid', gamma=.01),
    "RBF": SVC(),
    "Poly":SVC(kernel='poly', degree=3),
}
X, y = data.values[:, :1], data.values[:, 2]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
Ks = [2, 5, 10]
for name, clf in classifiers.items():
    print('CLASSIFIER:', name)
    for k in Ks:
        print('K: ', k)
        kf = KFold(n_splits=k)
        for iteration, train_index, val_index in enumerate(kf.split(X_train)):
            print()
    #       print("TRAIN:", train_index, "VAL:", val_index)
            X_train, X_val = X[train_index], X[val_index]
            y_train, y_val = y[train_index], y[val_index]

            clf.fit(X_train, y_train)
            print('Score: ', clf.score(X_val, y_val))
            print('Eout: ', 1 - clf.score(X_test, y_test))
# Out:
# CLASSIFIER: Sigmoid - gamma 1
# K:  2
# Score:  0.5589622641509434
# Eout:  0.42169811320754713
# Score:  0.5726415094339623
# Eout:  0.42641509433962266
# K:  5
# Score:  0.5424528301886793
# Eout:  0.41792452830188676
# Score:  0.6344339622641509
# Eout:  0.4226415094339623
# Score:  0.5094339622641509
# Eout:  0.42452830188679247
# Score:  0.5589622641509434
# Eout:  0.4226415094339623
# Score:  0.5424528301886793
# Eout:  0.42641509433962266
# K:  10
# Score:  0.5352941176470588
# Eout:  0.42169811320754713
# Score:  0.5235294117647059
# Eout:  0.4254716981132075
# Score:  0.6588235294117647
# Eout:  0.4235849056603773
# Score:  0.6352941176470588
# Eout:  0.4273584905660377
# Score:  0.5941176470588235
# Eout:  0.4273584905660377
# Score:  0.5882352941176471
# Eout:  0.4235849056603773
# Score:  0.4260355029585799
# Eout:  0.42641509433962266
# Score:  0.5562130177514792
# Eout:  0.4273584905660377
# Score:  0.514792899408284
# Eout:  0.42641509433962266
# Score:  0.4260355029585799
# Eout:  0.5518867924528301
# CLASSIFIER: Sigmoid - gamma .5
# K:  2
# Score:  0.43717277486910994
# Eout:  0.5349056603773585
# Score:  0.5124508519003932
# Eout:  0.55
# K:  5
# Score:  0.48366013071895425
# Eout:  0.5490566037735849
# Score:  0.47058823529411764
# Eout:  0.5433962264150943
# Score:  0.41830065359477125
# Eout:  0.5556603773584905
# Score:  0.39215686274509803
# Eout:  0.5462264150943397
# Score:  0.631578947368421
# Eout:  0.42641509433962266
# K:  10
# Score:  0.5645161290322581
# Eout:  0.5415094339622641
# Score:  0.5806451612903226
# Eout:  0.42169811320754713
# Score:  0.4918032786885246
# Eout:  0.4226415094339623
# Score:  0.5409836065573771
# Eout:  0.4273584905660377
